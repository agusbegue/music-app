# %%
import requests
import json

# %%
def refresh_headers():
    r = requests.post('https://accounts.spotify.com/api/token', data={
        'grant_type': 'refresh_token',
        'refresh_token': 'AQBUMI3FVqVNmfmxpWgBb4aGNZ6BzT7mf85XoC8Aps4K_RJnnqNm_aajnLOVIqnEOa5a_Qfg-n-a_axaVMr9gtF2205hvi9mi1IFT3n5Iep7DrLKtl5gl5T9RZ-_tmqTXiU',
        'client_id': '908d3e07450148849b073e188ba0216a',
        'client_secret': 'd14f7cf76e734ba1b32e43b79f5e48cb'
    })
    return {'Authorization': 'Bearer {}'.format(json.loads(r.content)['access_token']),
           'Content-Type': 'application/json'}

# %%
headers = refresh_headers()

# %% [markdown]
# ## Playlist

# %%
playlist = json.loads(requests.get('https://api.spotify.com/v1/playlists/37i9dQZEVXbMMy2roB9myp/tracks', headers=headers).content)

# %%
playlist['items'][0]
# Out:
# {'added_at': '2022-06-07T12:07:55Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7vXDAI8JwjW531ouMGbfcp'},
#      'href': 'https://api.spotify.com/v1/artists/7vXDAI8JwjW531ouMGbfcp',
#      'id': '7vXDAI8JwjW531ouMGbfcp',
#      'name': 'TINI',
#      'type': 'artist',
#      'uri': 'spotify:artist:7vXDAI8JwjW531ouMGbfcp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
# ...

# %% [markdown]
# ## Tracks

# %%
song1_id = '5RLtXgDduEE3qU2184BYpC'
song2_id = '1qK2fh2lg1VQxnrt4d0bKo'
acara = '5usHLPkjh7WmJSEWqZHVSE'
animal = '1lnogoGekR3zgFBpcVVkac'

# %% [markdown]
# ##### The actual track

# %%
tracks = json.loads(requests.get(f'https://api.spotify.com/v1/tracks?ids={acara}%2C{animal}', headers=headers).content)

# %%
tracks['tracks'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
t = {'a': 2}
dict(a, b=3)
# Out:
# {'a': 2, 'b': 3}

# %% [markdown]
# ##### Audio features

# %%
audio_features = json.loads(requests.get(f'https://api.spotify.com/v1/audio-features?ids={song1_id}%2C{song2_id}', headers=headers).content)

# %%
audio_features
# Out:
# {'audio_features': [{'danceability': 0.665,
#    'energy': 0.483,
#    'key': 5,
#    'loudness': -8.255,
#    'mode': 0,
#    'speechiness': 0.0472,
#    'acousticness': 0.578,
#    'instrumentalness': 9.57e-05,
#    'liveness': 0.112,
#    'valence': 0.803,
#    'tempo': 165.977,
#    'type': 'audio_features',
#    'id': '5RLtXgDduEE3qU2184BYpC',
#    'uri': 'spotify:track:5RLtXgDduEE3qU2184BYpC',
#    'track_href': 'https://api.spotify.com/v1/tracks/5RLtXgDduEE3qU2184BYpC',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RLtXgDduEE3qU2184BYpC',
#    'duration_ms': 190482,
#    'time_signature': 4},
#   {'danceability': 0.748,
#    'energy': 0.518,
#    'key': 3,
#    'loudness': -8.018,
#    'mode': 1,
#    'speechiness': 0.056,
#    'acousticness': 0.771,
#    'instrumentalness': 0,
#    'liveness': 0.103,
#    'valence': 0.4,
#    'tempo': 137.948,
#    'type': 'audio_features',
#    'id': '1qK2fh2lg1VQxnrt4d0bKo',
# ...

# %% [markdown]
# ## Artists

# %%
artist1_id = '5BS8KSKJPeLeXfABQx0bXl'
artist2_id = '6ASri4ePR7RlsvIQgWPJpS'
mari = '1DxLCyH42yaHKGK3cl5bvG'

# %% [markdown]
# ##### Raw data

# %%
artists = json.loads(requests.get(f'https://api.spotify.com/v1/artists?ids={artist1_id}%2C{artist2_id}', headers=headers).content)

# %% [markdown]
# ##### Top tracks

# %%
artist_top_tracks = json.loads(requests.get(f'https://api.spotify.com/v1/artists/{mari}/top-tracks?market=ES&limit=30', headers=headers).content)

# %%
artist_top_tracks
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vyhD5VmyZ7KMfW5gqLgo5'},
#       'href': 'https://api.spotify.com/v1/artists/1vyhD5VmyZ7KMfW5gqLgo5',
#       'id': '1vyhD5VmyZ7KMfW5gqLgo5',
#       'name': 'J Balvin',
#       'type': 'artist',
#       'uri': 'spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/11GmvpYnbgK0rSryPaV5BP'},
#     'href': 'https://api.spotify.com/v1/albums/11GmvpYnbgK0rSryPaV5BP',
#     'id': '11GmvpYnbgK0rSryPaV5BP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273922a7339d969b5f0262580f5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02922a7339d969b5f0262580f5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851922a7339d969b5f0262580f5',
#       'width': 64}],
# ...

# %%
len(artist_top_tracks['tracks'])
# Out:
# 10

# %% [markdown]
# ##### Albums

# %%
artist_albums = json.loads(requests.get(f'https://api.spotify.com/v1/artists/1DxLCyH42yaHKGK3cl5bvG/albums?limit=50&include_groups=single,album', headers=headers).content)

# %%
artist_albums
# Out:
# {'href': 'https://api.spotify.com/v1/artists/1DxLCyH42yaHKGK3cl5bvG/albums?offset=0&limit=50&include_groups=album,single',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DxLCyH42yaHKGK3cl5bvG'},
#      'href': 'https://api.spotify.com/v1/artists/1DxLCyH42yaHKGK3cl5bvG',
#      'id': '1DxLCyH42yaHKGK3cl5bvG',
#      'name': 'Maria Becerra',
#      'type': 'artist',
#      'uri': 'spotify:artist:1DxLCyH42yaHKGK3cl5bvG'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
# ...

# %%
artist_albums['items'][1]
# Out:
# {'album_group': 'single',
#  'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vR2qb8m9WHeZ5ByCbimq2'},
#    'href': 'https://api.spotify.com/v1/artists/0vR2qb8m9WHeZ5ByCbimq2',
#    'id': '0vR2qb8m9WHeZ5ByCbimq2',
#    'name': 'Reik',
#    'type': 'artist',
#    'uri': 'spotify:artist:0vR2qb8m9WHeZ5ByCbimq2'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1DxLCyH42yaHKGK3cl5bvG'},
#    'href': 'https://api.spotify.com/v1/artists/1DxLCyH42yaHKGK3cl5bvG',
#    'id': '1DxLCyH42yaHKGK3cl5bvG',
#    'name': 'Maria Becerra',
#    'type': 'artist',
#    'uri': 'spotify:artist:1DxLCyH42yaHKGK3cl5bvG'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
# ...

# %%
list(map(lambda f: (f['name'], f['release_date'], f['type'], f['album_type']), artist_albums['items']))
# Out:
# [('Animal', '2021-08-26', 'album', 'album'),
#  ('Los Tragos', '2021-11-25', 'album', 'single'),
#  ('Antes de Ti', '2021-10-07', 'album', 'single'),
#  ('Mal Acostumbrao', '2021-09-02', 'album', 'single'),
#  ('Wow Wow (feat. Becky G)', '2021-08-26', 'album', 'single'),
#  ('Te Necesito (Live Acoustic)', '2021-08-11', 'album', 'single'),
#  ('Mi Debilidad', '2021-07-29', 'album', 'single'),
#  ('BOBO', '2021-06-25', 'album', 'single'),
#  ('Cazame', '2021-06-10', 'album', 'single'),
#  ('Qué Más Pues?', '2021-05-28', 'album', 'single'),
#  ('Te Necesito', '2021-05-13', 'album', 'single'),
#  ('Miénteme', '2021-04-29', 'album', 'single'),
#  ('Si Yo Fuera Tú', '2021-03-19', 'album', 'single'),
#  ('Animal Pt. 1', '2021-02-25', 'album', 'single'),
#  ('Animal', '2021-01-07', 'album', 'single'),
#  ('AYNEA REMIX', '2020-12-17', 'album', 'single'),
#  ('Confiesalo', '2020-11-12', 'album', 'single'),
#  ('High (Remix)', '2020-09-03', 'album', 'single'),
# ...

# %% [markdown]
# ##### Album tracks

# %%
albums_tracks = json.loads(requests.get(f'https://api.spotify.com/v1/albums/?ids=2OXeXtTp8KR8TO21LbBIWP%2C74ubg9xT4sJ4FmNxcGHIK0', headers=headers).content)

# %%
albums_tracks['albums'][1]
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vR2qb8m9WHeZ5ByCbimq2'},
#    'href': 'https://api.spotify.com/v1/artists/0vR2qb8m9WHeZ5ByCbimq2',
#    'id': '0vR2qb8m9WHeZ5ByCbimq2',
#    'name': 'Reik',
#    'type': 'artist',
#    'uri': 'spotify:artist:0vR2qb8m9WHeZ5ByCbimq2'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1DxLCyH42yaHKGK3cl5bvG'},
#    'href': 'https://api.spotify.com/v1/artists/1DxLCyH42yaHKGK3cl5bvG',
#    'id': '1DxLCyH42yaHKGK3cl5bvG',
#    'name': 'Maria Becerra',
#    'type': 'artist',
#    'uri': 'spotify:artist:1DxLCyH42yaHKGK3cl5bvG'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
# ...
